# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Nyachomo\\OneDrive\\Desktop\\datascience'

# %%
df=pd.read_excel('datasets/nyeri.xlsx')

# %%
df.head(1)
# Out:
#         student_name  student_class                       student_course  \
# 0  Allan Thiga Maina  NNP/EIT4/25J1   ELECTRICAL INSTALLATION TECHNOLOGY
#
#    student_year student_gender student_category student_adm_no  \
# 0           1.0           Male              CBS          54056
#
#   attachment_period    year attachment_start_date attachment_end_date  \
# 0          sept-dec  2025.0            2025-09-01          2025-12-31
#
#           company_name                                        sector_name  \
# 0  SAMTECH ELECTRICALS  Electrical & Electronics Engineering, Electric...
#
#   placement_status      graded assigned_manual  \
# 0           Placed  Not Graded        Assigned
#
#    student_workbehaviour_grading_score  student_skills_grading_score  \
# 0                                 10.0                          38.6
#
#    student_knowledge_grading_score  student_final_score
# 0                              NaN                  NaN

# %%
#CHECK DATATYPE OF THE DATASETS
df.dtypes
# Out:
# student_name                            object
# student_class                              str
# student_course                             str
# student_year                           float64
# student_gender                             str
# student_category                           str
# student_adm_no                          object
# attachment_period                          str
# year                                   float64
# attachment_start_date                      str
# attachment_end_date                        str
# company_name                               str
# sector_name                                str
# placement_status                           str
# graded                                     str
# assigned_manual                            str
# student_workbehaviour_grading_score    float64
# student_skills_grading_score           float64
# student_knowledge_grading_score        float64
# student_final_score                    float64
# dtype: object

# %%
df['student_name'].dtype
# Out:
# dtype('O')

# %%
df['year'].dtype
# Out:
# dtype('float64')

# %%
df['student_year']=pd.to_numeric(df['student_year'],errors='coerce')

# %%
df['student_year'].dtype
# Out:
# dtype('float64')

# %%
df['student_year']=df['student_year'].astype('Int64')

# %%
df['student_year'].dtype
# Out:
# Int64Dtype()

# %%
df.dtypes
# Out:
# student_name                            object
# student_class                              str
# student_course                             str
# student_year                             Int64
# student_gender                             str
# student_category                           str
# student_adm_no                          object
# attachment_period                          str
# year                                   float64
# attachment_start_date                      str
# attachment_end_date                        str
# company_name                               str
# sector_name                                str
# placement_status                           str
# graded                                     str
# assigned_manual                            str
# student_workbehaviour_grading_score    float64
# student_skills_grading_score           float64
# student_knowledge_grading_score        float64
# student_final_score                    float64
# dtype: object

# %%
df['student_year']=df['student_year'].astype(float)

# %%
df.dtypes
# Out:
# student_name                            object
# student_class                              str
# student_course                             str
# student_year                           float64
# student_gender                             str
# student_category                           str
# student_adm_no                          object
# attachment_period                          str
# year                                   float64
# attachment_start_date                      str
# attachment_end_date                        str
# company_name                               str
# sector_name                                str
# placement_status                           str
# graded                                     str
# assigned_manual                            str
# student_workbehaviour_grading_score    float64
# student_skills_grading_score           float64
# student_knowledge_grading_score        float64
# student_final_score                    float64
# dtype: object

# %%
#CONVERT TO STRING
df['year']=df['year'].astype(str)

# %%
df.dtypes
# Out:
# student_name                            object
# student_class                              str
# student_course                             str
# student_year                           float64
# student_gender                             str
# student_category                           str
# student_adm_no                          object
# attachment_period                          str
# year                                       str
# attachment_start_date                      str
# attachment_end_date                        str
# company_name                               str
# sector_name                                str
# placement_status                           str
# graded                                     str
# assigned_manual                            str
# student_workbehaviour_grading_score    float64
# student_skills_grading_score           float64
# student_knowledge_grading_score        float64
# student_final_score                    float64
# dtype: object

# %%
#CONVERT TO CETGORYCAL DATATYPE
df['student_gender']=df['student_gender'].astype('category')

# %%
df.dtypes
# Out:
# student_name                             object
# student_class                               str
# student_course                              str
# student_year                            float64
# student_gender                         category
# student_category                            str
# student_adm_no                           object
# attachment_period                           str
# year                                        str
# attachment_start_date                       str
# attachment_end_date                         str
# company_name                                str
# sector_name                                 str
# placement_status                            str
# graded                                      str
# assigned_manual                             str
# student_workbehaviour_grading_score     float64
# student_skills_grading_score            float64
# student_knowledge_grading_score         float64
# student_final_score                     float64
# ...

# %%
df
# Out:
#                    student_name  student_class  \
# 0             Allan Thiga Maina  NNP/EIT4/25J1
# 1        Bernad Ndirangu Mwangi  NNP/EIT4/25J1
# 2           Isaac Kanja Kabuchu  NNP/EIT4/25J1
# 3             Isaac Kihagi Biru  NNP/EIT4/25J1
# 4            James Mugendi Mugi  NNP/EIT4/25J1
# ...                         ...            ...
# 17562  Patrick kariuki Gachomba       WFB424S1
# 17563         Peter Maina Wanja  NNP/WFB4/25J1
# 17564     Benjamin  Kioko  Paul  NNP/WFB5/24S1
# 17565     David Muriithi Abwavo  NNP/WFB5/24S1
# 17566            michae cheptoo  NNP/WFB5/23S1
#
#                                    student_course  student_year  \
# 0              ELECTRICAL INSTALLATION TECHNOLOGY           1.0
# 1              ELECTRICAL INSTALLATION TECHNOLOGY           1.0
# 2              ELECTRICAL INSTALLATION TECHNOLOGY           1.0
# 3              ELECTRICAL INSTALLATION TECHNOLOGY           1.0
# 4              ELECTRICAL INSTALLATION TECHNOLOGY           1.0
# ...

# %%
df['grade_boolean']=df['graded'].map({
    'Not Graded':'False',
    'Graded':'True'
})

# %%
df
# Out:
#                    student_name  student_class  \
# 0             Allan Thiga Maina  NNP/EIT4/25J1
# 1        Bernad Ndirangu Mwangi  NNP/EIT4/25J1
# 2           Isaac Kanja Kabuchu  NNP/EIT4/25J1
# 3             Isaac Kihagi Biru  NNP/EIT4/25J1
# 4            James Mugendi Mugi  NNP/EIT4/25J1
# ...                         ...            ...
# 17562  Patrick kariuki Gachomba       WFB424S1
# 17563         Peter Maina Wanja  NNP/WFB4/25J1
# 17564     Benjamin  Kioko  Paul  NNP/WFB5/24S1
# 17565     David Muriithi Abwavo  NNP/WFB5/24S1
# 17566            michae cheptoo  NNP/WFB5/23S1
#
#                                    student_course  student_year  \
# 0              ELECTRICAL INSTALLATION TECHNOLOGY           1.0
# 1              ELECTRICAL INSTALLATION TECHNOLOGY           1.0
# 2              ELECTRICAL INSTALLATION TECHNOLOGY           1.0
# 3              ELECTRICAL INSTALLATION TECHNOLOGY           1.0
# 4              ELECTRICAL INSTALLATION TECHNOLOGY           1.0
# ...

# %%
list(df.columns)
# Out:
# ['student_name',
#  'student_class',
#  'student_course',
#  'student_year',
#  'student_gender',
#  'student_category',
#  'student_adm_no',
#  'attachment_period',
#  'year',
#  'attachment_start_date',
#  'attachment_end_date',
#  'company_name',
#  'sector_name',
#  'placement_status',
#  'graded',
#  'assigned_manual',
#  'student_workbehaviour_grading_score',
#  'student_skills_grading_score',
#  'student_knowledge_grading_score',
#  'student_final_score',
#  'grade_boolean']

# %%
df.loc[:,['student_name','graded','grade_boolean']
]
# Out:
#                    student_name      graded grade_boolean
# 0             Allan Thiga Maina  Not Graded         False
# 1        Bernad Ndirangu Mwangi      Graded          True
# 2           Isaac Kanja Kabuchu  Not Graded         False
# 3             Isaac Kihagi Biru      Graded          True
# 4            James Mugendi Mugi      Graded          True
# ...                         ...         ...           ...
# 17562  Patrick kariuki Gachomba  Not Graded         False
# 17563         Peter Maina Wanja  Not Graded         False
# 17564     Benjamin  Kioko  Paul  Not Graded         False
# 17565     David Muriithi Abwavo  Not Graded         False
# 17566            michae cheptoo  Not Graded         False
#
# [17567 rows x 3 columns]
