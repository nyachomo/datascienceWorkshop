# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Nyachomo\\OneDrive\\Desktop\\datascience'

# %%
df=pd.read_excel('datasets/nyeri.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 17567 entries, 0 to 17566
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   student_name                         17567 non-null  object
#  1   student_class                        17567 non-null  str
#  2   student_course                       17566 non-null  str
#  3   student_year                         10470 non-null  float64
#  4   student_gender                       16960 non-null  str
#  5   student_category                     17567 non-null  str
#  6   student_adm_no                       17567 non-null  object
#  7   attachment_period                    15151 non-null  str
#  8   year                                 15151 non-null  float64
#  9   attachment_start_date                15151 non-null  str
#  10  attachment_end_date                  15151 non-null  str
# ...

# %%
df.shape
# Out:
# (17567, 20)

# %%
df.columns
# Out:
# Index(['student_name', 'student_class', 'student_course', 'student_year',
#        'student_gender', 'student_category', 'student_adm_no',
#        'attachment_period', 'year', 'attachment_start_date',
#        'attachment_end_date', 'company_name', 'sector_name',
#        'placement_status', 'graded', 'assigned_manual',
#        'student_workbehaviour_grading_score', 'student_skills_grading_score',
#        'student_knowledge_grading_score', 'student_final_score'],
#       dtype='str')

# %%
list(df.columns)
# Out:
# ['student_name',
#  'student_class',
#  'student_course',
#  'student_year',
#  'student_gender',
#  'student_category',
#  'student_adm_no',
#  'attachment_period',
#  'year',
#  'attachment_start_date',
#  'attachment_end_date',
#  'company_name',
#  'sector_name',
#  'placement_status',
#  'graded',
#  'assigned_manual',
#  'student_workbehaviour_grading_score',
#  'student_skills_grading_score',
#  'student_knowledge_grading_score',
#  'student_final_score']

# %%
statistical_summary=df.describe()

# %%
statistical_summary.to_excel('statistical_summary.xlsx')

# %%
#CHECK FOR MISSING VALUES
df.isnull().sum()
# Out:
# student_name                               0
# student_class                              0
# student_course                             1
# student_year                            7097
# student_gender                           607
# student_category                           0
# student_adm_no                             0
# attachment_period                       2416
# year                                    2416
# attachment_start_date                   2416
# attachment_end_date                     2416
# company_name                            5277
# sector_name                             6382
# placement_status                           0
# graded                                     0
# assigned_manual                            0
# student_workbehaviour_grading_score    10309
# student_skills_grading_score            9519
# student_knowledge_grading_score        10021
# student_final_score                    10728
# dtype: int64

# %%
#SECONDA OPTION OF CHECKING MISSING VALUES
df.isna().sum()
# Out:
# student_name                               0
# student_class                              0
# student_course                             1
# student_year                            7097
# student_gender                           607
# student_category                           0
# student_adm_no                             0
# attachment_period                       2416
# year                                    2416
# attachment_start_date                   2416
# attachment_end_date                     2416
# company_name                            5277
# sector_name                             6382
# placement_status                           0
# graded                                     0
# assigned_manual                            0
# student_workbehaviour_grading_score    10309
# student_skills_grading_score            9519
# student_knowledge_grading_score        10021
# student_final_score                    10728
# dtype: int64

# %%
#CHECK HOWMANY SHEET THE EXCEL IS CONTAINING
excel_file=pd.ExcelFile('datasets/nyeri.xlsx')
excel_file.sheet_names
# Out:
# ['Worksheet']

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Nyachomo\\OneDrive\\Desktop\\datascience'

# %%
os.path.exists(r'C:\\Users\\Nyachomo\\OneDrive\\Desktop\\datascience\\datasets\nyeri.xlsx')
# Out:
# True

# %%
df.isnull().values.any()
# Out:
# np.True_

# %%
df.isnull().sum()
# Out:
# student_name                               0
# student_class                              0
# student_course                             1
# student_year                            7097
# student_gender                           607
# student_category                           0
# student_adm_no                             0
# attachment_period                       2416
# year                                    2416
# attachment_start_date                   2416
# attachment_end_date                     2416
# company_name                            5277
# sector_name                             6382
# placement_status                           0
# graded                                     0
# assigned_manual                            0
# student_workbehaviour_grading_score    10309
# student_skills_grading_score            9519
# student_knowledge_grading_score        10021
# student_final_score                    10728
# dtype: int64

# %%
df.isna().sum()
# Out:
# student_name                               0
# student_class                              0
# student_course                             1
# student_year                            7097
# student_gender                           607
# student_category                           0
# student_adm_no                             0
# attachment_period                       2416
# year                                    2416
# attachment_start_date                   2416
# attachment_end_date                     2416
# company_name                            5277
# sector_name                             6382
# placement_status                           0
# graded                                     0
# assigned_manual                            0
# student_workbehaviour_grading_score    10309
# student_skills_grading_score            9519
# student_knowledge_grading_score        10021
# student_final_score                    10728
# dtype: int64

# %%
df.isna().values.any()
# Out:
# np.True_

# %%
df.isnull().sum().sum()
# Out:
# np.int64(69605)

# %%
df.isna().sum().sum()
# Out:
# np.int64(69605)

# %%
df.isna().sum()
# Out:
# student_name                               0
# student_class                              0
# student_course                             1
# student_year                            7097
# student_gender                           607
# student_category                           0
# student_adm_no                             0
# attachment_period                       2416
# year                                    2416
# attachment_start_date                   2416
# attachment_end_date                     2416
# company_name                            5277
# sector_name                             6382
# placement_status                           0
# graded                                     0
# assigned_manual                            0
# student_workbehaviour_grading_score    10309
# student_skills_grading_score            9519
# student_knowledge_grading_score        10021
# student_final_score                    10728
# dtype: int64

# %%
df["student_year"].isnull().values.any()
# Out:
# np.True_

# %%
df["student_year"].isnull().sum()
# Out:
# np.int64(7097)

# %%
students_missing_adm_no=df[df['student_year'].isnull()]

# %%
students_missing_adm_no.to_csv('students_missing_adm_no.csv',index=False)

# %%
df.loc[df['student_year'].isnull(),['student_name','student_class','student_adm_no','student_course']]
# Out:
#                    student_name      student_class student_adm_no  \
# 108         judy nyakio gichira      NNP/CMT6/25M2          42115
# 109         judy nyakio gichira      NNP/CMT6/25M2          42115
# 114      Wanjiru Kinuthia Talia      NNP/FDM4/24M1          42688
# 143        Jesse Mwangi Kimondo           MVM424M1          43870
# 144        Jesse Mwangi Kimondo           MVM424M1          43870
# ...                         ...                ...            ...
# 17535            STUDENT 4 SEL6       SEL6/024/M\t          SEL64
# 17551  Chrisjohn Githaiga Maina  \t\tNNP/WFB4/24M1          48549
# 17555      Karimi Wanja Kenneth  \t\tNNP/WFB4/24M1          49517
# 17561    Nahason Kihia Wangombe  \t\tNNP/WFB4/24M1          46319
# 17566            michae cheptoo      NNP/WFB5/23S1          46017
#
#                                           student_course
# 108    ARTISAN IN FASHION DESIGN AND GARMENT MAKING T...
# 109    ARTISAN IN FASHION DESIGN AND GARMENT MAKING T...
# ...

# %%
df[df['student_year'].isna() & df['student_gender'].isna()].shape
# Out:
# (219, 20)

# %%
df.loc[df['student_year'].isna() & df['student_gender'].isna()]
# Out:
#                student_name  student_class         student_course  \
# 3962   Adline Ndinda Kamala  NNP/cmt5/24s1  COSMETOLOGIST LEVEL 5
# 3965     Anne Wanjira Maina  NNP/cmt5/24s2  COSMETOLOGIST LEVEL 5
# 4038    Muthoni Maina Mercy  NNP/cmt5/24s1  COSMETOLOGIST LEVEL 5
# 4039    Muthoni Maina Mercy  NNP/cmt5/24s1  COSMETOLOGIST LEVEL 5
# 4067    Nyokabi Jane Wahome  NNP/cmt5/24s2  COSMETOLOGIST LEVEL 5
# ...                     ...            ...                    ...
# 17362                 42678       PLB523M1        PLUMBER LEVEL 5
# 17363                 42872       PLB523M1        PLUMBER LEVEL 5
# 17364                 42873       PLB523M1        PLUMBER LEVEL 5
# 17365                 42927       PLB523M1        PLUMBER LEVEL 5
# 17366                 43030       PLB523M1        PLUMBER LEVEL 5
#
#        student_year student_gender student_category  \
# 3962            NaN            NaN              CBS
# 3965            NaN            NaN              CBS
# ...

# %%
df[df.isna()]
# Out:
#       student_name student_class student_course  student_year student_gender  \
# 0              NaN           NaN            NaN           NaN            NaN
# 1              NaN           NaN            NaN           NaN            NaN
# 2              NaN           NaN            NaN           NaN            NaN
# 3              NaN           NaN            NaN           NaN            NaN
# 4              NaN           NaN            NaN           NaN            NaN
# ...            ...           ...            ...           ...            ...
# 17562          NaN           NaN            NaN           NaN            NaN
# 17563          NaN           NaN            NaN           NaN            NaN
# 17564          NaN           NaN            NaN           NaN            NaN
# 17565          NaN           NaN            NaN           NaN            NaN
# 17566          NaN           NaN            NaN           NaN            NaN
#
# ...

# %%
df.columns[~df.isnull().any()].tolist()
# Out:
# ['student_name',
#  'student_class',
#  'student_category',
#  'student_adm_no',
#  'placement_status',
#  'graded',
#  'assigned_manual']

# %%
df[~df.isnull().any(axis=1)].shape
# Out:
# (3998, 20)
