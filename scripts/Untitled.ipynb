# %%
import pandas as pd
import os

# %%
#GETTING WORKING DIRECTORY
os.getcwd()
# Out:
# 'C:\\Users\\Nyachomo\\OneDrive\\Desktop\\datascience'

# %%
df['student_workbehaviour_grading_score']=pd.to_numeric(df['student_workbehaviour_grading_score'],errors='coerce')
df['student_skills_grading_score']=pd.to_numeric(df['student_skills_grading_score'],errors='coerce')
df['student_final_score']=pd.to_numeric(df['student_final_score'],errors='coerce').astype('Int64')
df['student_knowledge_grading_score']=pd.to_numeric(df['student_knowledge_grading_score'],errors='coerce')
