# %%
import pandas as pd
import os

# %%
#GET CURRENT WORKING DIRECTORY
os.getcwd()
# Out:
# 'C:\\Users\\Nyachomo\\OneDrive\\Desktop\\datascience'

# %%
df=pd.read_excel('datasets/nyeri.xlsx')

# %%
df.shape
# Out:
# (17567, 20)

# %%
df.duplicated().sum()
# Out:
# np.int64(241)

# %%
#DISPLAYING DUPLICATES ROW
df[
    df.duplicated()
]
# Out:
#                       student_name    student_class  \
# 67                Jane Njeri Mburu    NNP/ANC6/25J1
# 144           Jesse Mwangi Kimondo         MVM424M1
# 184    Amulegah Shivega Joelosteen    NNP/AMT5/24S1
# 282           Erick Ndiragu Kimani  nnp/amc5/25s2-d
# 284           Erick Ndiragu Kimani  nnp/amc5/25s2-d
# ...                            ...              ...
# 12215           Neema Wanjiku Mwai    NNP/TTM6/25J1
# 12216           Neema Wanjiku Mwai    NNP/TTM6/25J1
# 12237       Winfred Wanjiku Mwangi     nnp/tt6/24s2
# 12246      Susan Nyaguthii Mwaniki  \tNNP/TTM5/24M2
# 12248      Susan Nyaguthii Mwaniki  \tNNP/TTM5/24M2
#
#                                 student_course  student_year student_gender  \
# 67                ANALYTICAL CHEMISTRY level 6           1.0         Female
# 144    ARTISAN MOTOR VEHICLE MECHANICS -YEAR 1           NaN           Male
# 184            AUTOMOTIVE MECHATRONICS LEVEL 5           NaN           Male
# ...

# %%
duplicates_all_columns=df[
    df.duplicated(keep=False)
]

# %%
duplicates_all_columns.to_excel('datasets/duplicates_all_columns.xlsx',index=False)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 17567 entries, 0 to 17566
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   student_name                         17567 non-null  object
#  1   student_class                        17567 non-null  str
#  2   student_course                       17566 non-null  str
#  3   student_year                         10470 non-null  float64
#  4   student_gender                       16960 non-null  str
#  5   student_category                     17567 non-null  str
#  6   student_adm_no                       17567 non-null  object
#  7   attachment_period                    15151 non-null  str
#  8   year                                 15151 non-null  float64
#  9   attachment_start_date                15151 non-null  str
#  10  attachment_end_date                  15151 non-null  str
# ...

# %%
df['student_class'].duplicated().any()
# Out:
# np.True_

# %%
df[
    df.duplicated()
]
# Out:
#                       student_name    student_class  \
# 67                Jane Njeri Mburu    NNP/ANC6/25J1
# 144           Jesse Mwangi Kimondo         MVM424M1
# 184    Amulegah Shivega Joelosteen    NNP/AMT5/24S1
# 282           Erick Ndiragu Kimani  nnp/amc5/25s2-d
# 284           Erick Ndiragu Kimani  nnp/amc5/25s2-d
# ...                            ...              ...
# 12215           Neema Wanjiku Mwai    NNP/TTM6/25J1
# 12216           Neema Wanjiku Mwai    NNP/TTM6/25J1
# 12237       Winfred Wanjiku Mwangi     nnp/tt6/24s2
# 12246      Susan Nyaguthii Mwaniki  \tNNP/TTM5/24M2
# 12248      Susan Nyaguthii Mwaniki  \tNNP/TTM5/24M2
#
#                                 student_course  student_year student_gender  \
# 67                ANALYTICAL CHEMISTRY level 6           1.0         Female
# 144    ARTISAN MOTOR VEHICLE MECHANICS -YEAR 1           NaN           Male
# 184            AUTOMOTIVE MECHATRONICS LEVEL 5           NaN           Male
# ...

# %%
duplicates_std_adm_no=df.loc[
    df['student_adm_no'].duplicated(keep=False),
    ['student_name','student_adm_no','student_class','student_course']
]

# %%
duplicates_std_adm_no.to_excel('datasets/duplicates_std_adm_no.xlsx')

# %%
counts=df['student_adm_no'].value_counts()
counts[counts>1]
# Out:
# student_adm_no
# 37585    10
# 48498     7
# 45000     7
# 47812     6
# 47501     6
#          ..
# 37024     2
# 38978     2
# 45017     2
# 37633     2
# 23936     2
# Name: count, Length: 2983, dtype: int64

# %%
subset_duplicates=df.loc[df.duplicated(
    subset=['student_adm_no','student_class','student_year','attachment_period','company_name','year'], keep=False),
     ['student_adm_no','student_class','student_year','attachment_period']
    ]

# %%
len(subset_duplicates)
# Out:
# 891

# %%
    df.duplicated(
        subset=['student_adm_no','student_class','student_year','attachment_period','company_name','year']
    ).sum()
# Out:
# np.int64(491)

# %%
df.groupby(['student_adm_no','student_class']).size()
# Out:
# student_adm_no        student_class
# 12                    \tNNP/ICT5/24J1      1
# 123                   NNP/ICT6/25S2        1
# 200                   CI001                1
# 500                   NNP/ICT5/24M1        1
# 600                   \tNNP/ICT6/24M2      1
#                                           ..
# Waweru Brian Kariuki  PLB4 23S1            1
# Waweru Chris Mwangi   PLB523M1             1
# cam001                NNP/CAM5/24J1        1
# cbet001               NNP/SLT6/25S3        2
# knec001               knec/001             1
# Length: 13992, dtype: int64

# %%
len(df)
# Out:
# 17567

# %%
df.duplicated().sum()
# Out:
# np.int64(241)

# %%
clean_dt1=df.drop_dulicate()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 clean_dt1=df.drop_dulicate()
#
# File ~\.conda\envs\data\Lib\site-packages\pandas\core\generic.py:6194, in NDFrame.__getattr__(self, name)
#    6190             and name not in self._accessors
#    6191             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6192         ):
#    6193             return self[name]
# -> 6194         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'drop_dulicate'
