# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Nyachomo\\OneDrive\\Desktop\\datascience'

# %%
df=pd.read_excel('datasets/nyeri.xlsx')

# %%
df.columns
# Out:
# Index(['student_name', 'student_class', 'student_course', 'student_year',
#        'student_gender', 'student_category', 'student_adm_no',
#        'attachment_period', 'year', 'attachment_start_date',
#        'attachment_end_date', 'company_name', 'sector_name',
#        'placement_status', 'graded', 'assigned_manual',
#        'student_workbehaviour_grading_score', 'student_skills_grading_score',
#        'student_knowledge_grading_score', 'student_final_score'],
#       dtype='str')

# %%
list(df.columns)
# Out:
# ['student_name',
#  'student_class',
#  'student_course',
#  'student_year',
#  'student_gender',
#  'student_category',
#  'student_adm_no',
#  'attachment_period',
#  'year',
#  'attachment_start_date',
#  'attachment_end_date',
#  'company_name',
#  'sector_name',
#  'placement_status',
#  'graded',
#  'assigned_manual',
#  'student_workbehaviour_grading_score',
#  'student_skills_grading_score',
#  'student_knowledge_grading_score',
#  'student_final_score']

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 17567 entries, 0 to 17566
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   student_name                         17567 non-null  object
#  1   student_class                        17567 non-null  str
#  2   student_course                       17566 non-null  str
#  3   student_year                         10470 non-null  float64
#  4   student_gender                       16960 non-null  str
#  5   student_category                     17567 non-null  str
#  6   student_adm_no                       17567 non-null  object
#  7   attachment_period                    15151 non-null  str
#  8   year                                 15151 non-null  float64
#  9   attachment_start_date                15151 non-null  str
#  10  attachment_end_date                  15151 non-null  str
# ...

# %%
df.describe()
# Out:
#        student_year          year  student_workbehaviour_grading_score  \
# count  10470.000000  15151.000000                          7258.000000
# mean       1.529131   2024.542340                            17.611298
# std        0.627985      1.005549                             5.447891
# min        1.000000   2023.000000                             0.000000
# 25%        1.000000   2024.000000                            18.500000
# 50%        1.000000   2025.000000                            20.000000
# 75%        2.000000   2025.000000                            20.000000
# max        6.000000   2026.000000                            20.000000
#
#        student_skills_grading_score  student_knowledge_grading_score  \
# count                   8048.000000                      7546.000000
# mean                      54.211767                        17.401365
# std                       13.934138                         5.441821
# ...

# %%
df.shape
# Out:
# (17567, 20)

# %%
df.isna().values.any()
# Out:
# np.True_

# %%
df.isnull().values.any()
# Out:
# np.True_

# %%
df.isna().sum()
# Out:
# student_name                               0
# student_class                              0
# student_course                             1
# student_year                            7097
# student_gender                           607
# student_category                           0
# student_adm_no                             0
# attachment_period                       2416
# year                                    2416
# attachment_start_date                   2416
# attachment_end_date                     2416
# company_name                            5277
# sector_name                             6382
# placement_status                           0
# graded                                     0
# assigned_manual                            0
# student_workbehaviour_grading_score    10309
# student_skills_grading_score            9519
# student_knowledge_grading_score        10021
# student_final_score                    10728
# dtype: int64

# %%
df.isnull().sum()
# Out:
# student_name                               0
# student_class                              0
# student_course                             1
# student_year                            7097
# student_gender                           607
# student_category                           0
# student_adm_no                             0
# attachment_period                       2416
# year                                    2416
# attachment_start_date                   2416
# attachment_end_date                     2416
# company_name                            5277
# sector_name                             6382
# placement_status                           0
# graded                                     0
# assigned_manual                            0
# student_workbehaviour_grading_score    10309
# student_skills_grading_score            9519
# student_knowledge_grading_score        10021
# student_final_score                    10728
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# np.int64(69605)

# %%
df.isnull().sum().sum()
# Out:
# np.int64(69605)

# %%
df['student_year'].isnull().sum()
# Out:
# np.int64(7097)

# %%
df['student_year'].isna().sum()
# Out:
# np.int64(7097)

# %%
df[df['student_year'].isnull()]
# Out:
#                    student_name      student_class  \
# 108         judy nyakio gichira      NNP/CMT6/25M2
# 109         judy nyakio gichira      NNP/CMT6/25M2
# 114      Wanjiru Kinuthia Talia      NNP/FDM4/24M1
# 143        Jesse Mwangi Kimondo           MVM424M1
# 144        Jesse Mwangi Kimondo           MVM424M1
# ...                         ...                ...
# 17535            STUDENT 4 SEL6       SEL6/024/M\t
# 17551  Chrisjohn Githaiga Maina  \t\tNNP/WFB4/24M1
# 17555      Karimi Wanja Kenneth  \t\tNNP/WFB4/24M1
# 17561    Nahason Kihia Wangombe  \t\tNNP/WFB4/24M1
# 17566            michae cheptoo      NNP/WFB5/23S1
#
#                                           student_course  student_year  \
# 108    ARTISAN IN FASHION DESIGN AND GARMENT MAKING T...           NaN
# 109    ARTISAN IN FASHION DESIGN AND GARMENT MAKING T...           NaN
# 114    ARTISAN IN FASHION DESIGN AND GARMENT MAKING T...           NaN
# ...

# %%
student_missing_student_year=df.loc[
    df['student_year'].isnull(),
    ['student_name','student_class','student_course','student_category']
    ]

# %%
student_missing_student_year.to_excel('datasets/student_missing_student_year.xlsx',index=False)

# %%
os.path.exists('datasets/student_missing_student_year.xlsx')
# Out:
# True

# %%
df[
    df['student_year'].isnull() &
    df['attachment_period'].isnull()
]
# Out:
#                 student_name    student_class  \
# 12295  Irene wairimu Mithamo           Alumni
# 12302    maurice john ikonze  NNP/AGE6/26M-M1
# 12439   Allan Macharia Kamau           Alumni
# 12576  FRANKLIN MUTUA MUTUKU        AMC6/23S1
# 12594   Joan Wanjiru Wanjiru    NNP/BRS3/26M1
# ...                      ...              ...
# 17480                  36159  \tNNP/SLT6/24M2
# 17532         STUDENT 1 SEL6     SEL6/024/M\t
# 17533         STUDENT 2 SEL6     SEL6/024/M\t
# 17534         STUDENT 3 SEL6     SEL6/024/M\t
# 17535         STUDENT 4 SEL6     SEL6/024/M\t
#
#                                   student_course  student_year student_gender  \
# 12295                                        NaN           NaN         Female
# 12302             AGRICULTURAL EXTENSION LEVEL 6           NaN           Male
# 12439  AUTOMOTIVE ENGINEERING TECHNICIAN LEVEL 5           NaN           Male
# 12576              AUTOMOTIVE TECHNICIAN LEVEL 6           NaN           Male
# ...

# %%
df.loc[
    #df['student_year'].isnull(), 
    df['attachment_period'].isnull(),
    ['student_name','student_class','student_category','student_year']
]
# Out:
#                 student_name    student_class student_category  student_year
# 12295  Irene wairimu Mithamo           Alumni             KNEC           NaN
# 12302    maurice john ikonze  NNP/AGE6/26M-M1              CBS           NaN
# 12439   Allan Macharia Kamau           Alumni             KNEC           NaN
# 12576  FRANKLIN MUTUA MUTUKU        AMC6/23S1              CBS           NaN
# 12594   Joan Wanjiru Wanjiru    NNP/BRS3/26M1             CBET           NaN
# ...                      ...              ...              ...           ...
# 17480                  36159  \tNNP/SLT6/24M2              CBS           NaN
# 17532         STUDENT 1 SEL6     SEL6/024/M\t             CBET           NaN
# 17533         STUDENT 2 SEL6     SEL6/024/M\t             CBET           NaN
# 17534         STUDENT 3 SEL6     SEL6/024/M\t             CBET           NaN
# 17535         STUDENT 4 SEL6     SEL6/024/M\t             CBET           NaN
#
# [2416 rows x 4 columns]

# %%
df[
    df.isnull().all(axis=1)
]
# Out:
# Empty DataFrame
# Columns: [student_name, student_class, student_course, student_year, student_gender, student_category, student_adm_no, attachment_period, year, attachment_start_date, attachment_end_date, company_name, sector_name, placement_status, graded, assigned_manual, student_workbehaviour_grading_score, student_skills_grading_score, student_knowledge_grading_score, student_final_score]
# Index: []

# %%
df.isnull().all(axis=1).sum()
# Out:
# np.int64(0)

# %%
df[
    df.isnull().any(axis=1)
]
# Out:
#                    student_name    student_class  \
# 0             Allan Thiga Maina    NNP/EIT4/25J1
# 2           Isaac Kanja Kabuchu    NNP/EIT4/25J1
# 10       Michael Odhiambo Owino    NNP/EIT4/25J1
# 11      Mwangi Wambugu Fredrick    NNP/EIT4/25J1
# 14         Ndungi Tobias Bachia  NNP/EIT3/26J-J1
# ...                         ...              ...
# 17562  Patrick kariuki Gachomba         WFB424S1
# 17563         Peter Maina Wanja    NNP/WFB4/25J1
# 17564     Benjamin  Kioko  Paul    NNP/WFB5/24S1
# 17565     David Muriithi Abwavo    NNP/WFB5/24S1
# 17566            michae cheptoo    NNP/WFB5/23S1
#
#                                           student_course  student_year  \
# 0                     ELECTRICAL INSTALLATION TECHNOLOGY           1.0
# 2                     ELECTRICAL INSTALLATION TECHNOLOGY           1.0
# 10                    ELECTRICAL INSTALLATION TECHNOLOGY           1.0
# 11                    ELECTRICAL INSTALLATION TECHNOLOGY           1.0
# ...

# %%
df.isnull().any(axis=1).sum()
# Out:
# np.int64(13569)

# %%
df.isnull().any().sum()
# Out:
# np.int64(13)

# %%
df.columns[
    df.isnull().any()
]
# Out:
# Index(['student_course', 'student_year', 'student_gender', 'attachment_period',
#        'year', 'attachment_start_date', 'attachment_end_date', 'company_name',
#        'sector_name', 'student_workbehaviour_grading_score',
#        'student_skills_grading_score', 'student_knowledge_grading_score',
#        'student_final_score'],
#       dtype='str')

# %%
list(
    df.columns[
        df.isnull().any()
    ]
)
# Out:
# ['student_course',
#  'student_year',
#  'student_gender',
#  'attachment_period',
#  'year',
#  'attachment_start_date',
#  'attachment_end_date',
#  'company_name',
#  'sector_name',
#  'student_workbehaviour_grading_score',
#  'student_skills_grading_score',
#  'student_knowledge_grading_score',
#  'student_final_score']

# %%
list(
    df.columns[
        ~df.isnull().any()
    ]
)
# Out:
# ['student_name',
#  'student_class',
#  'student_category',
#  'student_adm_no',
#  'placement_status',
#  'graded',
#  'assigned_manual']

# %%
df.isnull().sum().sum()
# Out:
# np.int64(69605)

# %%
df.shape
# Out:
# (17567, 20)

# %%
no_missing_values=df.dropna()

# %%
no_missing_values.shape
# Out:
# (3998, 20)
