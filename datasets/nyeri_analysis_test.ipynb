# %% [markdown]
# Retail Sales and Customer Analytics Using

# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'c:\\Users\\Nyachomo\\OneDrive\\Desktop\\datascience\\datasets'

# %%
df=pd.read_excel('nyeri.xlsx')
df.head(3)
# Out:
#              student_name  student_class                       student_course  \
# 0       Allan Thiga Maina  NNP/EIT4/25J1   ELECTRICAL INSTALLATION TECHNOLOGY
# 1  Bernad Ndirangu Mwangi  NNP/EIT4/25J1   ELECTRICAL INSTALLATION TECHNOLOGY
# 2     Isaac Kanja Kabuchu  NNP/EIT4/25J1   ELECTRICAL INSTALLATION TECHNOLOGY
#
#    student_year student_gender student_category student_adm_no  \
# 0           1.0           Male              CBS          54056
# 1           1.0           Male              CBS          51732
# 2           1.0           Male              CBS          53862
#
#   attachment_period    year attachment_start_date attachment_end_date  \
# 0          sept-dec  2025.0            2025-09-01          2025-12-31
# 1          sept-dec  2025.0            2025-09-01          2025-12-31
# 2          sept-dec  2025.0            2025-09-01          2025-12-31
#
#                   company_name  \
# 0          SAMTECH ELECTRICALS
# 1  KARATINA SUBCOUNTY HOSPITAL
# ...
