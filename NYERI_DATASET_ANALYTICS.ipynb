# %%
import pandas as pd
import os

# %%
#os.getcwd()
# Out:
# 'C:\\Users\\Nyachomo\\OneDrive\\Desktop\\datascience'

# %%
df=pd.read_excel('datasets/nyeri.xlsx')

# %%
#FINDING HOW MANY COLUMSN AND ROWS
df.shape
# Out:
# (17567, 20)

# %%
list(df.columns)
# Out:
# ['student_name',
#  'student_class',
#  'student_course',
#  'student_year',
#  'student_gender',
#  'student_category',
#  'student_adm_no',
#  'attachment_period',
#  'year',
#  'attachment_start_date',
#  'attachment_end_date',
#  'company_name',
#  'sector_name',
#  'placement_status',
#  'graded',
#  'assigned_manual',
#  'student_workbehaviour_grading_score',
#  'student_skills_grading_score',
#  'student_knowledge_grading_score',
#  'student_final_score']
